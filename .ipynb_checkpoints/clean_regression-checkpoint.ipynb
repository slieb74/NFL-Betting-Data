# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.learning_curve import validation_curve
import statsmodels.api as sm
import math
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from scipy import stats
from scipy.special import boxcox1p
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('nfl_betting_df.csv', index_col = 0)

# %%
df['exp_win_difference'] = df.home_exp_win_pct- df.away_exp_win_pct
df = df[df.schedule_season > 1978]

# %%
df['total_ppg'] = (df.h_ppg + df.a_ppg)
df['total_points_against'] = (df.h_papg + df.a_papg)
df['last_four_difference'] = (df.home_win_pct_last_4 - df.away_win_pct_last_4)

# %%
df[['weather_temperature', 'weather_wind_mph', 'weather_humidity']]=df[['weather_temperature', 'weather_wind_mph', 'weather_humidity']].fillna(value=np.round(df.mean(),3))
df[['over_under_line']]=df[['over_under_line']].fillna(value=(np.round(df.mean()*2)/2))

# %%
df = df.fillna(value = 0)

# %%
df.index = range(0, len(df))

# %%
df.columns
# Out:
# Index(['schedule_season', 'schedule_week', 'team_home', 'team_away',
#        'team_favorite_id', 'spread_favorite', 'over_under_line',
#        'weather_detail', 'weather_temperature', 'weather_wind_mph',
#        'weather_humidity', 'score_home', 'score_away', 'point_total',
#        'over_under_result', 'score_difference', 'home_id', 'away_id',
#        'home_favorite', 'favorite_covered', 'winning_team', 'losing_team',
#        'home_wins', 'home_losses', 'home_ties', 'away_wins', 'away_losses',
#        'away_ties', 'home_points_for', 'home_points_against',
#        'away_points_for', 'away_points_against', 'h_games', 'a_games',
#        'home_win_pct', 'away_win_pct', 'win_pct_diff', 'h_ppg', 'h_papg',
#        'a_ppg', 'a_papg', 'home_pt_diff_pg', 'away_pt_diff_pg', 'pt_diff_pg',
#        'home_exp_win_pct', 'away_exp_win_pct', 'home_win_pct_last_4',
#        'away_win_pct_last_4', 'exp_win_difference', 'total_ppg',
#        'total_points_against', 'last_four_difference'],
#       dtype='object')

# %%
reg_df = df[(df.schedule_week > 1) & (df.schedule_week < 19) & (df.schedule_season>2001)]
week5_df = df[(df.schedule_week > 4) & (df.schedule_week < 19) & (df.schedule_season>2001)]

# %%
spread_samples = np.random.choice(week5_df.spread_favorite,25)
sample_means = spread_samples.mean()

def n_samples(arr,sample_size,n_samples):
    size = sample_size
    sample_means=[]
    
    for n in range(n_samples):
        sample_means.append(np.random.choice(arr,size).mean())
    
    return sample_means

x = n_samples(week5_df.spread_favorite,25,1000)

#sns.distplot(x)

ax1 = n_samples(week5_df.spread_favorite[(week5_df.spread_favorite>-12.5) & (week5_df.home_favorite==1)],50,15000)
ax2 = n_samples(week5_df.spread_favorite[(week5_df.spread_favorite>-12.5) & (week5_df.home_favorite==0)],50,15000)
sns.distplot(ax1)
sns.distplot(ax2)
sum(week5_df.spread_favorite<-12.5)/len(week5_df)
np.sum(ax1)/len(ax1)
np.sum(ax2)/len(ax2)
# Out:
# /Users/SamLiebman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/SamLiebman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# -4.420276

# %%
rw5 = np.random.choice(week5_df.spread_favorite,10)

ax = sns.distplot(week5_df.spread_favorite)
ax.set_xlim(-10,0)
# Out:
# /Users/SamLiebman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (-10, 0)

# %%
sns.distplot((reg_df.spread_favorite[reg_df['spread_favorite']>-10]))
# Out:
# /Users/SamLiebman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
reg_df['spread_favorite'].median()
# Out:
# -4.5

# %%
reg_df.columns
# Out:
# Index(['schedule_season', 'schedule_week', 'team_home', 'team_away',
#        'team_favorite_id', 'spread_favorite', 'over_under_line',
#        'weather_detail', 'weather_temperature', 'weather_wind_mph',
#        'weather_humidity', 'score_home', 'score_away', 'point_total',
#        'over_under_result', 'score_difference', 'home_id', 'away_id',
#        'home_favorite', 'favorite_covered', 'winning_team', 'losing_team',
#        'home_wins', 'home_losses', 'home_ties', 'away_wins', 'away_losses',
#        'away_ties', 'home_points_for', 'home_points_against',
#        'away_points_for', 'away_points_against', 'h_games', 'a_games',
#        'home_win_pct', 'away_win_pct', 'win_pct_diff', 'h_ppg', 'h_papg',
#        'a_ppg', 'a_papg', 'home_pt_diff_pg', 'away_pt_diff_pg', 'pt_diff_pg',
#        'home_exp_win_pct', 'away_exp_win_pct', 'home_win_pct_last_4',
#        'away_win_pct_last_4', 'exp_win_difference', 'total_ppg',
#        'total_points_against', 'last_four_difference'],
#       dtype='object')

# %%
pivot = reg_df.pivot_table(index='spread_favorite', columns='favorite_covered',
                    aggfunc={'favorite_covered':len}, fill_value = 0)

# %%
pivot['row_total'] = 0
for index, row in pivot.iterrows():
    row.row_total = sum(row)

# %%
covered = pivot.favorite_covered[1]
no_cover = pivot.favorite_covered[0]
push = pivot.favorite_covered[2]

# %%
spreads = sorted(set(reg_df.spread_favorite))
x = np.array([spread for spread in spreads if spread > -15 and spread < 0])

# %%
y_covered = [covered[value]/pivot['row_total'][value] for value in x]
y_no_cover = [no_cover[value]/pivot['row_total'][value] for value in x]
y_push = [push[value]/pivot['row_total'][value] for value in x]

# %%
plt.figure(figsize = (10,10))
plt.bar(x-.3,y_covered, label = 'cover', width = .3)
plt.bar(x,y_no_cover, label = 'no cover', width = .3)
plt.bar(x+.3,y_push, label = 'push', width = .3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=x,
    y=y_covered,
    name='Covered'
)
trace2 = go.Bar(
    x=x,
    y=y_no_cover,
    name='No Cover'
)

trace3 = go.Bar(
    x=x,
    y=y_push,
    name='Push'
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~slieb74/51.embed" height="525px" width="100%"></iframe>

# %%
x = reg_df.corr()
x_dict = x['over_under_line'].to_dict()
sorted_dict = sorted(x_dict.items(), key = lambda x:x[1])
sorted_dict
# Out:
# [('weather_wind_mph', -0.27814438839587063),
#  ('away_losses', -0.09181107897061887),
#  ('home_losses', -0.08261468736976238),
#  ('weather_humidity', -0.07296270790762051),
#  ('favorite_covered', -0.06089438793056482),
#  ('home_favorite', -0.04783828371692238),
#  ('spread_favorite', -0.02676209774446886),
#  ('schedule_week', -0.01590567168302309),
#  ('h_games', -0.013207615072821465),
#  ('a_games', -0.012557184401268516),
#  ('home_ties', -0.009323614004445693),
#  ('pt_diff_pg', -0.009019590703124431),
#  ('exp_win_difference', -0.0027615639900368705),
#  ('win_pct_diff', -0.0016914052458963243),
#  ('last_four_difference', 0.0008104096904615186),
#  ('score_difference', 0.004869988893768626),
#  ('away_ties', 0.0285009517966309),
#  ('home_wins', 0.06290691375775394),
#  ('away_wins', 0.07262458799908296),
#  ('away_points_against', 0.07738696378310155),
#  ('home_points_against', 0.09375010316977914),
#  ('away_win_pct_last_4', 0.10290023606164597),
#  ('home_win_pct_last_4', 0.10353097316603686),
#  ('home_win_pct', 0.10678726690160871),
#  ('away_win_pct', 0.10958492845271159),
#  ('home_pt_diff_pg', 0.13261107358761548),
#  ('home_exp_win_pct', 0.1334015628786559),
#  ('away_exp_win_pct', 0.13640600494488056),
#  ('away_pt_diff_pg', 0.14397849421755843),
#  ('weather_temperature', 0.16114889135156646),
#  ('away_points_for', 0.16472148561605904),
#  ('home_points_for', 0.16869618730462313),
#  ('score_away', 0.20097912732807455),
#  ('score_home', 0.20453339069569343),
#  ('a_papg', 0.2450886867509945),
#  ('h_papg', 0.2749293316185052),
#  ('point_total', 0.295038812479638),
#  ('schedule_season', 0.33713288737552516),
#  ('total_points_against', 0.3612893021869393),
#  ('a_ppg', 0.42931606338934575),
#  ('h_ppg', 0.444267154311653),
#  ('total_ppg', 0.6051452378127731),
#  ('over_under_line', 1.0)]

# %%
reg_df
# Out:
#       schedule_season  schedule_week             team_home  \
# 5387             2002              2       Atlanta Falcons
# 5388             2002              2      Baltimore Ravens
# 5389             2002              2     Carolina Panthers
# 5390             2002              2      Cleveland Browns
# 5391             2002              2        Dallas Cowboys
# 5392             2002              2    Indianapolis Colts
# 5393             2002              2    Kansas City Chiefs
# 5394             2002              2     Minnesota Vikings
# 5395             2002              2    New Orleans Saints
# 5396             2002              2         New York Jets
# 5397             2002              2   Pittsburgh Steelers
# 5398             2002              2    San Diego Chargers
# 5399             2002              2   San Francisco 49ers
# 5400             2002              2      Seattle Seahawks
# 5401             2002              2        St. Louis Rams
# 5402             2002              2   Washington Redskins
# 5403             2002              3     Arizona Cardinals
# 5404             2002              3       Atlanta Falcons
# 5405             2002              3         Chicago Bears
# 5406             2002              3        Denver Broncos
# 5407             2002              3         Detroit Lions
# 5408             2002              3        Houston Texans
# 5409             2002              3        Miami Dolphins
# 5410             2002              3     Minnesota Vikings
# 5411             2002              3  New England Patriots
# 5412             2002              3       New York Giants
# 5413             2002              3   Philadelphia Eagles
# 5414             2002              3   San Francisco 49ers
# 5415             2002              3      Tennessee Titans
# 5416             2002              3  Tampa Bay Buccaneers
# ...               ...            ...                   ...
# 9602             2017             16     Arizona Cardinals
# 9603             2017             16     Carolina Panthers
# 9604             2017             16         Chicago Bears
# 9605             2017             16    Cincinnati Bengals
# 9606             2017             16        Dallas Cowboys
# 9607             2017             16    Kansas City Chiefs
# 9608             2017             16  New England Patriots
# 9609             2017             16    New Orleans Saints
# 9610             2017             16         New York Jets
# 9611             2017             16   San Francisco 49ers
# 9612             2017             16      Tennessee Titans
# 9613             2017             16   Washington Redskins
# 9614             2017             16        Houston Texans
# 9615             2017             16   Philadelphia Eagles
# 9616             2017             17       Atlanta Falcons
# 9617             2017             17      Baltimore Ravens
# 9618             2017             17        Denver Broncos
# 9619             2017             17         Detroit Lions
# 9620             2017             17    Indianapolis Colts
# 9621             2017             17  Los Angeles Chargers
# 9622             2017             17      Los Angeles Rams
# 9623             2017             17        Miami Dolphins
# 9624             2017             17     Minnesota Vikings
# 9625             2017             17  New England Patriots
# 9626             2017             17       New York Giants
# 9627             2017             17   Philadelphia Eagles
# 9628             2017             17   Pittsburgh Steelers
# 9629             2017             17      Seattle Seahawks
# 9630             2017             17  Tampa Bay Buccaneers
# 9631             2017             17      Tennessee Titans
#
#                  team_away team_favorite_id  spread_favorite  over_under_line  \
# 5387         Chicago Bears              ATL             -2.5             45.0
# 5388  Tampa Bay Buccaneers               TB             -4.5             32.0
# 5389         Detroit Lions              CAR             -3.0             35.5
# 5390    Cincinnati Bengals              CLE             -3.5             39.0
# 5391      Tennessee Titans              TEN             -3.5             37.5
# 5392        Miami Dolphins             PICK              0.0             47.0
# 5393  Jacksonville Jaguars               KC             -3.5             46.0
# 5394         Buffalo Bills              MIN             -3.5             49.0
# 5395     Green Bay Packers               GB             -2.5             45.5
# 5396  New England Patriots              NYJ             -1.0             41.0
# 5397       Oakland Raiders              PIT             -4.0             39.5
# 5398        Houston Texans              LAC            -13.5             34.0
# 5399        Denver Broncos               SF             -3.5             44.0
# 5400     Arizona Cardinals              SEA             -4.0             40.5
# 5401       New York Giants              LAR            -12.0             46.0
# 5402   Philadelphia Eagles              PHI             -3.0             44.0
# 5403    San Diego Chargers              LAC             -2.5             39.0
# 5404    Cincinnati Bengals              ATL             -7.0             42.5
# 5405    New Orleans Saints               NO             -2.0             40.5
# 5406         Buffalo Bills              DEN             -7.5             47.0
# 5407     Green Bay Packers               GB             -7.5             44.0
# 5408    Indianapolis Colts              IND            -10.5             38.0
# 5409         New York Jets              MIA             -6.0             40.5
# 5410     Carolina Panthers              MIN             -6.5             44.5
# 5411    Kansas City Chiefs               NE             -8.5             43.5
# 5412      Seattle Seahawks              NYG             -5.5             39.0
# 5413        Dallas Cowboys              PHI            -10.0             36.5
# 5414   Washington Redskins               SF            -10.0             44.0
# 5415      Cleveland Browns              TEN             -4.5             40.5
# 5416        St. Louis Rams              LAR             -1.5             44.0
# ...                    ...              ...              ...              ...
# 9602       New York Giants              ARI             -3.0             39.0
# 9603  Tampa Bay Buccaneers              CAR            -10.0             46.5
# 9604      Cleveland Browns              CHI             -5.5             37.0
# 9605         Detroit Lions              DET             -3.5             43.5
# 9606      Seattle Seahawks              DAL             -4.5             47.0
# 9607        Miami Dolphins               KC            -11.0             43.5
# 9608         Buffalo Bills               NE            -11.0             47.5
# 9609       Atlanta Falcons               NO             -5.5             52.0
# 9610  Los Angeles Chargers              LAC             -7.5             42.5
# 9611  Jacksonville Jaguars              JAX             -4.0             43.0
# 9612      Los Angeles Rams              LAR             -5.5             46.0
# 9613        Denver Broncos              WAS             -3.0             39.5
# 9614   Pittsburgh Steelers              PIT             -8.0             45.5
# 9615       Oakland Raiders              PHI            -10.0             46.0
# 9616     Carolina Panthers              ATL             -5.0             44.5
# 9617    Cincinnati Bengals              BAL             -8.0             40.0
# 9618    Kansas City Chiefs              DEN             -3.0             37.5
# 9619     Green Bay Packers              DET             -7.5             44.5
# 9620        Houston Texans              IND             -5.5             41.5
# 9621       Oakland Raiders              LAC             -7.0             43.0
# 9622   San Francisco 49ers               SF             -6.0             44.5
# 9623         Buffalo Bills              BUF             -2.5             41.5
# 9624         Chicago Bears              MIN            -13.5             38.5
# 9625         New York Jets               NE            -17.0             43.5
# 9626   Washington Redskins              WAS             -4.5             41.0
# 9627        Dallas Cowboys              DAL             -3.5             41.0
# 9628      Cleveland Browns              PIT             -5.0             38.5
# 9629     Arizona Cardinals              SEA             -8.0             38.0
# 9630    New Orleans Saints               NO             -6.0             49.0
# 9631  Jacksonville Jaguars              TEN             -2.5             40.0
#
#      weather_detail  weather_temperature  weather_wind_mph  \
# 5387           DOME                 72.0               0.0
# 5388              0                 73.0               8.0
# 5389              0                 70.0              10.0
# 5390              0                 72.0              10.0
# 5391              0                 79.0              12.0
# 5392           DOME                 72.0               0.0
# 5393              0                 67.0               9.0
# 5394           DOME                 72.0               0.0
# 5395           DOME                 72.0               0.0
# 5396              0                 75.0              13.0
# 5397              0                 71.0               7.0
# 5398              0                 68.0               8.0
# 5399              0                 62.0              16.0
# 5400              0                 61.0               7.0
# 5401           DOME                 72.0               0.0
# 5402              0                 75.0              12.0
# 5403              0                 89.0               6.0
# 5404           DOME                 72.0               0.0
# 5405              0                 59.0              11.0
# 5406              0                 52.0              13.0
# 5407           DOME                 72.0               0.0
# 5408           DOME                 72.0               0.0
# 5409              0                 83.0              12.0
# 5410           DOME                 72.0               0.0
# 5411              0                 74.0              12.0
# 5412              0                 76.0              12.0
# 5413              0                 77.0               9.0
# 5414              0                 61.0              14.0
# 5415              0                 72.0               7.0
# 5416              0                 80.0               8.0
# ...             ...                  ...               ...
# 9602           DOME                 72.0               0.0
# 9603              0                 55.0               6.0
# 9604              0                 24.0               8.0
# 9605              0                 35.0               2.0
# 9606           DOME                 72.0               0.0
# 9607              0                 23.0              15.0
# 9608              0                 35.0               7.0
# 9609           DOME                 72.0               0.0
# 9610              0                 40.0               6.0
# 9611              0                 52.0               0.0
# 9612              0                 39.0              11.0
# 9613              0                 43.0               7.0
# 9614           DOME                 72.0               0.0
# 9615              0                 29.0              15.0
# 9616           DOME                 72.0               0.0
# 9617              0                 19.0              12.0
# 9618              0                 17.0               4.0
# 9619           DOME                 72.0               0.0
# 9620           DOME                 72.0               0.0
# 9621              0                 62.0               2.0
# 9622              0                 67.0               3.0
# 9623              0                 71.0               9.0
# 9624           DOME                 72.0               0.0
# 9625              0                 13.0              14.0
# 9626              0                 16.0              16.0
# 9627              0                 19.0              17.0
# 9628              0                 11.0               3.0
# 9629              0                 40.0               7.0
# 9630              0                 71.0               3.0
# 9631              0                 23.0               5.0
#
#               ...           away_pt_diff_pg  pt_diff_pg  home_exp_win_pct  \
# 5387          ...                     4.000      -7.000          0.368063
# 5388          ...                    -6.000       3.000          0.180159
# 5389          ...                   -28.000      31.000          0.819841
# 5390          ...                   -28.000      27.000          0.458620
# 5391          ...                     3.000     -12.000          0.037651
# 5392          ...                    28.000     -25.000          0.662566
# 5393          ...                    -3.000       4.000          0.541380
# 5394          ...                    -6.000       2.000          0.280768
# 5395          ...                     3.000       3.000          0.818520
# 5396          ...                    16.000     -10.000          0.753910
# 5397          ...                    14.000     -30.000          0.013061
# 5398          ...                     9.000      19.000          0.999932
# 5399          ...                     7.000      -4.000          0.740480
# 5400          ...                    -8.000      -6.000          0.029665
# 5401          ...                    -3.000      -4.000          0.119861
# 5402          ...                    -3.000      11.000          0.856384
# 5403          ...                    24.500     -23.000          0.593309
# 5404          ...                   -20.500      18.500          0.383019
# 5405          ...                    10.500      -8.000          0.670859
# 5406          ...                     0.000       8.500          0.921152
# 5407          ...                    -6.000     -20.000          0.001868
# 5408          ...                    -2.500      -3.500          0.101970
# 5409          ...                   -15.500      33.500          0.986339
# 5410          ...                    13.500     -18.500          0.280297
# 5411          ...                    -3.000      29.500          0.999320
# 5412          ...                   -12.500      13.500          0.571312
# 5413          ...                    -0.500      14.000          0.967218
# 5414          ...                   -11.000       7.500          0.248896
# 5415          ...                     6.000      -8.500          0.340211
# 5416          ...                    -6.000      15.500          0.949635
# ...           ...                       ...         ...               ...
# 9602          ...                    -9.071       2.571          0.146717
# 9603          ...                    -3.643       6.857          0.696312
# 9604          ...                   -11.071       6.785          0.223939
# 9605          ...                     1.357      -6.500          0.186372
# 9606          ...                     2.000      -0.214          0.609347
# 9607          ...                    -6.429      10.500          0.730994
# 9608          ...                    -3.000      11.643          0.892965
# 9609          ...                     2.571       5.929          0.886235
# 9610          ...                     4.000      -8.071          0.261202
# 9611          ...                    11.786     -17.786          0.166758
# 9612          ...                    11.857     -13.500          0.395422
# 9613          ...                    -5.286       1.429          0.280169
# 9614          ...                     4.714      -9.071          0.263783
# 9615          ...                    -3.071      14.428          0.934790
# 9616          ...                     3.200      -1.467          0.612968
# 9617          ...                    -4.200      10.600          0.845776
# 9618          ...                     4.867     -10.867          0.163525
# 9619          ...                    -2.667       3.334          0.539433
# 9620          ...                    -5.933      -4.134          0.060798
# 9621          ...                    -3.467       7.667          0.765885
# 9622          ...                    -4.867      16.200          0.935795
# 9623          ...                    -4.200      -2.867          0.131110
# 9624          ...                    -2.867      10.667          0.898731
# 9625          ...                    -4.267      13.734          0.910184
# 9626          ...                    -2.533      -7.467          0.057062
# 9627          ...                     1.067      10.133          0.936156
# 9628          ...                   -11.467      17.734          0.835378
# 9629          ...                    -4.533       7.000          0.656221
# 9630          ...                     8.600     -12.200          0.283162
# 9631          ...                    10.267     -12.067          0.386489
#
#       away_exp_win_pct home_win_pct_last_4  away_win_pct_last_4  \
# 5387          0.719232                0.00                 0.25
# 5388          0.181480                0.00                 0.00
# 5389          0.004504                0.25                 0.00
# 5390          0.000068                0.00                 0.00
# 5391          0.666962                0.00                 0.25
# 5392          0.995496                0.25                 0.25
# 5393          0.337434                0.25                 0.00
# 5394          0.246090                0.00                 0.00
# 5395          0.631937                0.25                 0.25
# 5396          0.986939                0.25                 0.25
# 5397          0.970335                0.00                 0.25
# 5398          0.962349                0.25                 0.25
# 5399          0.880139                0.25                 0.25
# 5400          0.143616                0.00                 0.00
# 5401          0.259520                0.00                 0.00
# 5402          0.333038                0.25                 0.00
# 5403          0.999945                0.25                 0.50
# 5404          0.000553                0.00                 0.00
# 5405          0.922889                0.50                 0.50
# 5406          0.500000                0.50                 0.25
# 5407          0.233759                0.00                 0.25
# 5408          0.342740                0.25                 0.25
# 5409          0.036680                0.50                 0.25
# 5410          0.995231                0.00                 0.50
# 5411          0.349223                0.50                 0.25
# 5412          0.032028                0.25                 0.00
# 5413          0.459023                0.25                 0.25
# 5414          0.065004                0.25                 0.25
# 5415          0.794789                0.25                 0.25
# 5416          0.170147                0.25                 0.00
# ...                ...                 ...                  ...
# 9602          0.077509                0.50                 0.00
# 9603          0.281624                0.75                 0.00
# 9604          0.042860                0.25                 0.00
# 9605          0.579237                0.25                 0.50
# 9606          0.626589                0.75                 0.50
# 9607          0.152291                0.50                 0.50
# 9608          0.305589                0.75                 0.75
# 9609          0.663117                0.50                 0.75
# 9610          0.750575                0.25                 0.75
# 9611          0.962853                0.75                 0.75
# 9612          0.942984                0.50                 0.75
# 9613          0.193176                0.50                 0.50
# 9614          0.770695                0.00                 0.75
# 9615          0.309090                0.75                 0.50
# 9616          0.696132                0.50                 0.75
# 9617          0.232508                0.75                 0.25
# 9618          0.769029                0.50                 0.75
# 9619          0.333942                0.50                 0.50
# 9620          0.195460                0.00                 0.00
# 9621          0.284287                0.75                 0.25
# 9622          0.222538                0.75                 1.00
# 9623          0.243356                0.50                 0.50
# 9624          0.300399                0.75                 0.50
# 9625          0.246116                0.75                 0.25
# 9626          0.348612                0.00                 0.50
# 9627          0.566914                0.75                 0.75
# 9628          0.035621                0.75                 0.00
# 9629          0.222632                0.50                 0.50
# 9630          0.891453                0.00                 0.75
# 9631          0.936944                0.25                 0.75
#
#      exp_win_difference total_ppg  total_points_against  last_four_difference
# 5387          -0.351169     61.00                 60.00                 -0.25
# 5388          -0.001321     27.00                 36.00                  0.00
# 5389           0.815337     31.00                 56.00                  0.25
# 5390           0.458552     45.00                 74.00                  0.00
# 5391          -0.629311     37.00                 43.00                 -0.25
# 5392          -0.332930     77.00                 46.00                  0.00
# 5393           0.203946     65.00                 67.00                  0.25
# 5394           0.034678     54.00                 64.00                  0.00
# 5395           0.186584     63.00                 54.00                  0.00
# 5396          -0.233029     67.00                 45.00                  0.00
# 5397          -0.957274     45.00                 47.00                 -0.25
# 5398           0.037583     53.00                 16.00                  0.00
# 5399          -0.139659     39.00                 29.00                  0.00
# 5400          -0.113951     40.00                 62.00                  0.00
# 5401          -0.139659     29.00                 39.00                  0.00
# 5402           0.523346     55.00                 50.00                  0.25
# 5403          -0.406636     52.50                 26.50                 -0.25
# 5404           0.382466     30.00                 52.50                  0.00
# 5405          -0.252030     51.00                 38.00                  0.00
# 5406           0.421152     61.50                 53.00                  0.25
# 5407          -0.231890     42.50                 74.50                 -0.25
# 5408          -0.240770     31.50                 40.00                  0.00
# 5409           0.949659     57.00                 54.50                  0.25
# 5410          -0.714935     51.50                 43.00                 -0.50
# 5411           0.650098     65.00                 41.50                  0.25
# 5412           0.539284     34.50                 46.00                  0.25
# 5413           0.508194     46.00                 33.00                  0.00
# 5414           0.183892     34.00                 48.50                  0.00
# 5415          -0.454578     49.50                 46.00                  0.00
# 5416           0.779488     41.00                 37.50                  0.25
# ...                 ...       ...                   ...                   ...
# 9602           0.069208     33.86                 49.43                  0.50
# 9603           0.414688     44.00                 44.43                  0.75
# 9604           0.181079     31.50                 46.86                  0.25
# 9605          -0.392865     42.21                 46.00                 -0.25
# 9606          -0.017242     46.93                 43.14                  0.25
# 9607           0.578702     43.64                 46.00                  0.00
# 9608           0.587375     47.07                 41.43                  0.00
# 9609           0.223117     51.35                 40.28                 -0.25
# 9610          -0.489372     42.57                 42.64                 -0.50
# 9611          -0.796095     44.78                 39.00                  0.00
# 9612          -0.547562     52.43                 42.22                 -0.25
# 9613           0.086993     39.93                 49.07                  0.00
# 9614          -0.506911     47.36                 47.00                 -0.75
# 9615           0.625700     51.36                 43.07                  0.25
# 9616          -0.083164     45.60                 40.66                 -0.25
# 9617           0.613268     41.80                 39.60                  0.50
# 9618          -0.605503     43.54                 44.67                 -0.25
# 9619           0.205491     45.60                 47.60                  0.00
# 9620          -0.134662     37.67                 53.67                  0.00
# 9621           0.481598     41.07                 40.34                  0.50
# 9622           0.713257     50.80                 44.34                 -0.25
# 9623          -0.112246     36.34                 47.60                  0.00
# 9624           0.598332     40.86                 35.93                  0.25
# 9625           0.664068     48.27                 43.06                  0.50
# 9626          -0.291550     37.33                 49.87                 -0.50
# 9627           0.369242     53.67                 41.40                  0.00
# 9628           0.799757     39.20                 44.40                  0.75
# 9629           0.433589     40.73                 42.80                  0.00
# 9630          -0.608291     48.54                 43.54                 -0.75
# 9631          -0.550455     48.40                 39.94                 -0.50
#
# [3841 rows x 52 columns]

# %%
reg_df.describe()
# Out:
#        schedule_season  schedule_week  spread_favorite  over_under_line  \
# count      3841.000000    3841.000000      3841.000000      3841.000000
# mean       2009.501953       9.651914        -5.419943        43.199948
# std           4.611360       4.684961         3.426142         4.713206
# min        2002.000000       2.000000       -26.500000        30.000000
# 25%        2006.000000       6.000000        -7.000000        40.000000
# 50%        2010.000000      10.000000        -4.500000        43.500000
# 75%        2014.000000      14.000000        -3.000000        46.500000
# max        2017.000000      17.000000         0.000000        60.000000
#
#        weather_temperature  weather_wind_mph  weather_humidity   score_home  \
# count           3841.00000       3841.000000       3841.000000  3841.000000
# mean              59.83598          6.247852         65.391817    23.253840
# std               15.59030          5.457698         12.433429    10.322451
# min                0.00000          0.000000          4.000000     0.000000
# 25%               49.00000          1.000000         64.000000    16.000000
# 50%               63.00000          6.000000         66.552000    23.000000
# 75%               72.00000         10.000000         68.000000    30.000000
# max               93.00000         40.000000        100.000000    62.000000
#
#         score_away  point_total          ...           away_pt_diff_pg  \
# count  3841.000000  3841.000000          ...               3841.000000
# mean     20.697214    43.951054          ...                  0.306306
# std      10.144719    14.066498          ...                  8.134176
# min       0.000000     3.000000          ...                -42.000000
# 25%      13.000000    34.000000          ...                 -5.000000
# 50%      20.000000    43.000000          ...                  0.500000
# 75%      27.000000    53.000000          ...                  5.571000
# max      59.000000   106.000000          ...                 42.000000
#
#         pt_diff_pg  home_exp_win_pct  away_exp_win_pct  home_win_pct_last_4  \
# count  3841.000000       3841.000000       3841.000000          3841.000000
# mean     -0.581775          0.489658          0.512084             0.409691
# std      11.366746          0.316927          0.318766             0.276171
# min     -52.000000          0.000000          0.000000             0.000000
# 25%      -7.667000          0.193552          0.217616             0.250000
# 50%      -0.428000          0.486835          0.529577             0.500000
# 75%       6.875000          0.781734          0.812959             0.500000
# max      54.000000          1.000000          1.000000             1.000000
#
#        away_win_pct_last_4  exp_win_difference    total_ppg  \
# count          3841.000000         3841.000000  3841.000000
# mean              0.427428           -0.022467    43.668854
# std               0.275013            0.447746     8.266455
# min               0.000000           -0.998244     0.000000
# 25%               0.250000           -0.336171    38.300000
# 50%               0.500000           -0.017929    43.500000
# 75%               0.500000            0.289001    48.910000
# max               1.000000            1.000000    83.000000
#
#        total_points_against  last_four_difference
# count           3841.000000           3841.000000
# mean              43.637272             -0.017736
# std                7.647113              0.361957
# min                9.000000             -1.000000
# 25%               38.890000             -0.250000
# 50%               43.730000              0.000000
# 75%               48.500000              0.250000
# max               88.000000              1.000000
#
# [8 rows x 43 columns]

# %%
def poly_regression(x, y, degree_range, xlim_min, xlim_max, ylim_min, ylim_max,xfit1, xfit2, alpha = .75,s = 5,width = 2.5):
    plt.figure(figsize = (10,10))
#     split = train_test_split(x, y)
#     X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
#     x = X_train
#     y = y_train
#     plt.scatter(x, y, s = s, alpha = alpha)
    plt.ylim(ylim_min, ylim_max)
    plt.xlim(xlim_min,xlim_max)
    if str(y) == str(reg_df.over_under_line):
        y1 = y[reg_df['over_under_result']=='over']
        y2 = y[reg_df['over_under_result']=='under']
        x1 = x[reg_df['over_under_result']=='over']
        x2 = x[reg_df['over_under_result']=='under']
        plt.scatter(x1, y1, s = s, alpha = alpha, color = 'green', label = 'Over')
        plt.scatter(x2, y2, s = s, alpha = .4, color = 'purple', label = 'Under')
    else:
        y1 = y[reg_df['favorite_covered']==1]
        y2 = y[reg_df['favorite_covered']==0]
        x1 = x[reg_df['favorite_covered']==1]
        x2 = x[reg_df['favorite_covered']==0]
        plt.scatter(x1, y1, s = s, alpha = alpha, color = 'green',label = 'Covered')
        plt.scatter(x2, y2, s = s, alpha = .4, color = 'purple', label ='No Cover')
    for degree in degree_range:
        poly_model = make_pipeline(PolynomialFeatures(degree),
                               LinearRegression())
        poly_model.fit(x[:, np.newaxis], y)
        xfit = np.linspace(xfit1,xfit2, 10000)
        yfit = poly_model.predict(xfit[:, np.newaxis])
        plt.plot(xfit, yfit, label = 'degree={}'.format(degree),linewidth=width)
    plt.legend(loc = 'best')

# %%
def regression_evaluation(target, X_list):
    target = target
    X = X_list 
    X2 = sm.add_constant(X)
    # model = sm.ols(formula = 'over_under_line ~ np.power(total_points_against, 1)', data = reg_df).fit()

    est = sm.OLS(target, X2)
    est2 = est.fit()
    
    y_predicted = est2.fittedvalues
    y_actual = target
    rmse = math.sqrt(mean_squared_error(y_actual, y_predicted))
    residuals = y_actual-y_predicted
    
    plt.scatter(y_predicted,residuals)
    check = round(rmse_check(y_predicted, y_actual) - rmse)
    print(est2.summary())
    plt.scatter(y_predicted,residuals)
    
    print('RMSE=' + str(rmse) + ', check =' + str(check))

# %%
def rmse_check(predictions, targets):

    differences = predictions - targets                       #the DIFFERENCEs.

    differences_squared = differences ** 2                    #the SQUAREs of ^

    mean_of_differences_squared = differences_squared.mean()  #the MEAN of ^

    rmse_val = np.sqrt(mean_of_differences_squared)           #ROOT of ^

    return rmse_val                                           #get the ^

# %% [markdown]
# # OVER/UNDER

# %% [markdown]
# # Variable 1 -Total Points Against

# %%
poly_regression((reg_df.total_points_against), reg_df.over_under_line, [1],15,85, 25, 65,10,150)

# %%
regression_evaluation(reg_df.over_under_line, reg_df.total_points_against)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     576.3
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):          8.92e-119
# Time:                        17:54:19   Log-Likelihood:                -11136.
# No. Observations:                3841   AIC:                         2.228e+04
# Df Residuals:                    3839   BIC:                         2.229e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   33.4830      0.411     81.482      0.000      32.677      34.289
# total_points_against     0.2227      0.009     24.007      0.000       0.204       0.241
# ==============================================================================
# Omnibus:                       34.210   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.010
# Skew:                           0.232   Prob(JB):                     2.50e-08
# Kurtosis:                       2.938   Cond. No.                         257.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=4.39427423998682, check =0.0

# %% [markdown]
# # VARIABLE 2 -TOTAL PPG

# %%
poly_regression((reg_df.total_ppg), reg_df.over_under_line, [1,2],15,85, 25, 65,10,150)

# %%
regression_evaluation(reg_df.over_under_line, (reg_df.total_ppg**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     2218.
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        17:54:20   Log-Likelihood:                -10529.
# No. Observations:                3841   AIC:                         2.106e+04
# Df Residuals:                    3839   BIC:                         2.107e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.1329      0.326     86.404      0.000      27.495      28.771
# total_ppg      0.3450      0.007     47.097      0.000       0.331       0.359
# ==============================================================================
# Omnibus:                        5.897   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                5.885
# Skew:                          -0.096   Prob(JB):                       0.0527
# Kurtosis:                       3.008   Cond. No.                         239.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.7517656568252153, check =0.0

# %% [markdown]
# ## VARIABLE 3 -WEATHER HUMIDITY

# %%
poly_regression(reg_df.weather_humidity, reg_df.over_under_line, [1],-5,100, 25, 65,-15,150)

# %%
regression_evaluation(reg_df.over_under_line, (reg_df.weather_humidity**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     20.55
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           6.00e-06
# Time:                        17:54:21   Log-Likelihood:                -11394.
# No. Observations:                3841   AIC:                         2.279e+04
# Df Residuals:                    3839   BIC:                         2.281e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               45.0086      0.406    110.817      0.000      44.212      45.805
# weather_humidity    -0.0277      0.006     -4.533      0.000      -0.040      -0.016
# ==============================================================================
# Omnibus:                       15.598   Durbin-Watson:                   1.716
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.766
# Skew:                           0.154   Prob(JB):                     0.000377
# Kurtosis:                       2.942   Cond. No.                         356.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=4.700031434196068, check =-0.0

# %% [markdown]
# # VARIABLE 4 - WIND MPH

# %%
poly_regression(reg_df.weather_wind_mph, reg_df.over_under_line, [1],-5,40, 25, 65,-10,60)

# %%
regression_evaluation(reg_df.over_under_line, (reg_df.weather_wind_mph**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     321.9
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           3.47e-69
# Time:                        17:54:22   Log-Likelihood:                -11250.
# No. Observations:                3841   AIC:                         2.250e+04
# Df Residuals:                    3839   BIC:                         2.252e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               44.7007      0.111    402.496      0.000      44.483      44.918
# weather_wind_mph    -0.2402      0.013    -17.942      0.000      -0.266      -0.214
# ==============================================================================
# Omnibus:                       29.122   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.642
# Skew:                           0.215   Prob(JB):                     3.66e-07
# Kurtosis:                       3.014   Cond. No.                         12.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=4.5266297509541396, check =-0.0

# %% [markdown]
# # VARIABLE 5 - Weather Temp

# %%
poly_regression(reg_df.weather_temperature, reg_df.over_under_line, [1],-5,100, 25, 65,-10,110)

# %%
regression_evaluation(reg_df.over_under_line, (reg_df.weather_temperature**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     102.4
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           9.20e-24
# Time:                        17:54:22   Log-Likelihood:                -11354.
# No. Observations:                3841   AIC:                         2.271e+04
# Df Residuals:                    3839   BIC:                         2.272e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  40.2849      0.298    135.295      0.000      39.701      40.869
# weather_temperature     0.0487      0.005     10.117      0.000       0.039       0.058
# ==============================================================================
# Omnibus:                       19.433   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.675
# Skew:                           0.175   Prob(JB):                     5.34e-05
# Kurtosis:                       2.979   Cond. No.                         245.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=4.6509989719805995, check =0.0

# %% [markdown]
# # ALL VARIABLES FOR OVER/UNDER

# %%
regression_evaluation(reg_df.over_under_line, reg_df[['weather_wind_mph', 'weather_humidity', 'total_points_against', 'total_ppg','weather_temperature']].values)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     1000.
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        17:54:23   Log-Likelihood:                -9801.6
# No. Observations:                3841   AIC:                         1.962e+04
# Df Residuals:                    3835   BIC:                         1.965e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.9184      0.567     31.616      0.000      16.807      19.030
# x1            -0.1360      0.010    -13.637      0.000      -0.156      -0.116
# x2            -0.0129      0.004     -3.178      0.001      -0.021      -0.005
# x3             0.2287      0.007     34.660      0.000       0.216       0.242
# x4             0.3484      0.006     57.011      0.000       0.336       0.360
# x5             0.0297      0.003      8.556      0.000       0.023       0.037
# ==============================================================================
# Omnibus:                       41.799   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.216
# Skew:                           0.085   Prob(JB):                     6.90e-15
# Kurtosis:                       3.615   Cond. No.                     1.23e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.23e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# RMSE=3.1046762921257103, check =0.0

# %% [markdown]
# # SPREAD

# %% [markdown]
# # Last 4 Games win %

# %%
poly_regression(reg_df.last_four_difference, reg_df.spread_favorite, [1,2,3,4],-1,1, -25, 0,-1,1)
plt.yticks(np.arange(-25,0,.5))
plt.xticks(np.arange(-1,1,.25));

# %%
regression_evaluation(reg_df.spread_favorite, (reg_df.last_four_difference**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        spread_favorite   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     326.0
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           5.11e-70
# Time:                        17:54:24   Log-Likelihood:                -10023.
# No. Observations:                3841   AIC:                         2.005e+04
# Df Residuals:                    3839   BIC:                         2.006e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -5.4669      0.053   -102.868      0.000      -5.571      -5.363
# last_four_difference    -2.6484      0.147    -18.057      0.000      -2.936      -2.361
# ==============================================================================
# Omnibus:                      522.812   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              796.431
# Skew:                          -0.970   Prob(JB):                    1.14e-173
# Kurtosis:                       4.101   Cond. No.                         2.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.288880150910651, check =-0.0

# %% [markdown]
# # WIN % DIFF REJECTED DUE TO LOW HIGH CORRELATION WITH EXP WINS

# %%
poly_regression(reg_df.win_pct_diff, reg_df.spread_favorite, [1,2],-1,1, -25, 0,-1,1)

# %%
regression_evaluation(reg_df.spread_favorite, (reg_df.win_pct_diff**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        spread_favorite   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     394.6
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           1.17e-83
# Time:                        17:54:25   Log-Likelihood:                -9991.7
# No. Observations:                3841   AIC:                         1.999e+04
# Df Residuals:                    3839   BIC:                         2.000e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -5.4802      0.053   -103.916      0.000      -5.584      -5.377
# win_pct_diff    -2.7580      0.139    -19.864      0.000      -3.030      -2.486
# ==============================================================================
# Omnibus:                      492.974   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              725.787
# Skew:                          -0.945   Prob(JB):                    2.50e-158
# Kurtosis:                       3.982   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.262156002357872, check =0.0

# %% [markdown]
# # First Variable- Home Favorite

# %%
poly_regression(reg_df.home_favorite, reg_df.spread_favorite, [1],-.01,1.01, -25, 0,-1,1)
plt.yticks(np.arange(-26.5,0,1));

# %%
regression_evaluation(reg_df.spread_favorite, (reg_df.home_favorite**1))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        spread_favorite   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     151.9
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):           2.90e-34
# Time:                        17:54:26   Log-Likelihood:                -10105.
# No. Observations:                3841   AIC:                         2.021e+04
# Df Residuals:                    3839   BIC:                         2.023e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -4.5399      0.090    -50.634      0.000      -4.716      -4.364
# home_favorite    -1.3877      0.113    -12.326      0.000      -1.608      -1.167
# ==============================================================================
# Omnibus:                      604.946   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              981.909
# Skew:                          -1.063   Prob(JB):                    6.04e-214
# Kurtosis:                       4.270   Cond. No.                         3.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.3598595981889763, check =0.0

# %%
# data = {"a":[2, 3, 5], "b":[2, 3, 5], "c":[2, 3, 5]}
# model = sm.ols(formula = 'a ~ np.power(b, 2) + b + c', data = reg_df).fit()

# %% [markdown]
# # SECOND VARIABLE - Exp Win Difference

# %%
poly_regression(reg_df.exp_win_difference, reg_df.spread_favorite, [2,3,4],-1,1, -25, 0,-1,1)

# %%
regression_evaluation(reg_df.spread_favorite, (reg_df.exp_win_difference**2))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        spread_favorite   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     897.4
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):          2.22e-177
# Time:                        17:54:26   Log-Likelihood:                -9776.1
# No. Observations:                3841   AIC:                         1.956e+04
# Df Residuals:                    3839   BIC:                         1.957e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -4.1326      0.066    -62.843      0.000      -4.261      -4.004
# exp_win_difference    -6.4071      0.214    -29.957      0.000      -6.826      -5.988
# ==============================================================================
# Omnibus:                      321.787   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              447.045
# Skew:                          -0.688   Prob(JB):                     8.42e-98
# Kurtosis:                       3.949   Cond. No.                         4.48
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.084122987748407, check =-0.0

# %%
regression_evaluation(reg_df.spread_favorite, reg_df[['last_four_difference', 'exp_win_difference', 'favorite_covered']].values)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        spread_favorite   R-squared:                       0.167
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     255.6
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):          3.12e-151
# Time:                        17:54:27   Log-Likelihood:                -9829.7
# No. Observations:                3841   AIC:                         1.967e+04
# Df Residuals:                    3837   BIC:                         1.969e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -6.0249      0.069    -87.557      0.000      -6.160      -5.890
# x1            -0.6791      0.187     -3.624      0.000      -1.046      -0.312
# x2            -2.6911      0.152    -17.680      0.000      -2.989      -2.393
# x3             0.9977      0.086     11.535      0.000       0.828       1.167
# ==============================================================================
# Omnibus:                      490.954   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              750.044
# Skew:                          -0.914   Prob(JB):                    1.35e-163
# Kurtosis:                       4.159   Cond. No.                         5.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.1274018291241865, check =-0.0

# %% [markdown]
# # WEEK- REJECTED LOW PREDICTABILITY

# %%
poly_regression(reg_df.schedule_week, reg_df.spread_favorite, [1],0,20, -25, 0,0,25)
plt.yticks(np.arange(-25,0,.5))
plt.xticks(np.arange(0,20,1));

# %%
# def log_log_regression(x, y, degree_range, xlim_min, xlim_max, ylim_min, ylim_max,xfit1, xfit2, alpha = .75,s = 5,width = 2.5):
# #     log_x=np.log(x+.01)
# #     log_y=np.log(y+.01)
    
#     split = train_test_split(x,y)
#     print(split[0])
#     print(split[1])
#     print(split[2])
#     print(split[3])

#     X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
#     plt.figure(figsize = (10,10))
#     plt.scatter(X_train, y_train, s = s, alpha = alpha)
#     plt.ylim(ylim_min, ylim_max)
#     plt.xlim(xlim_min,xlim_max)
    
#     log_model = LogisticRegression(random_state=0)
#     #log_model = sm.Logit(y_train,X_train)
#     log_model.fit(x[:, np.newaxis], y)
#     xfit = np.linspace(xfit1,xfit2, 10000)
#     yfit = log_model.predict(xfit[:, np.newaxis])
#     plt.plot(xfit, yfit, linewidth=width)#label = 'degree={}'.format(degree),
# #     for degree in degree_range:
# # #         log_model = make_pipeline(PolynomialFeatures(degree),
# # #                                LogisticRegression())
        
# #         #log_model.fit(log_x[:, np.newaxis], log_y)
        
#     plt.legend(loc = 'best')
    
def log_log_regression(x, y, degree_range, xlim_min, xlim_max, ylim_min, ylim_max,xfit1, xfit2, alpha = .75,s = 5,width = 2.5):
    #create figure and set size and axis lims
    plt.figure(figsize = (10,10))
    plt.ylim(ylim_min, ylim_max)
    plt.xlim(xlim_min,xlim_max)
    
    #split inputs into training and test sets
    split = train_test_split(np.log(x+.01), np.log(np.abs(y)+.01))
    X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
    x = X_train
    y = y_train
    plt.scatter(x, y, s = s, alpha = alpha)

    #conditional to plot points in diff color depending on game outcome
    if str(y) == str(reg_df.over_under_line):
        y1 = y[reg_df['over_under_result']=='over']
        y2 = y[reg_df['over_under_result']=='under']
        x1 = x[reg_df['over_under_result']=='over']
        x2 = x[reg_df['over_under_result']=='under']
        plt.scatter(x1, y1, s = s, alpha = alpha, color = 'green', label = 'Over')
        plt.scatter(x2, y2, s = s, alpha = .4, color = 'purple', label = 'Under')
    else:
        y1 = y[reg_df['favorite_covered']==1]
        y2 = y[reg_df['favorite_covered']==0]
        x1 = x[reg_df['favorite_covered']==1]
        x2 = x[reg_df['favorite_covered']==0]
        plt.scatter(x1, y1, s = s, alpha = alpha, color = 'green',label = 'Covered')
        plt.scatter(x2, y2, s = s, alpha = .4, color = 'purple', label ='No Cover')
    
    for degree in degree_range:
        poly_model = make_pipeline(PolynomialFeatures(degree),
                               LinearRegression())
        poly_model.fit(x[:, np.newaxis], y)
        xfit = np.linspace(xfit1,xfit2, 10000)
        yfit = poly_model.predict(xfit[:, np.newaxis])
        plt.plot(xfit, yfit, label = 'degree={}'.format(degree),linewidth=width)
    plt.legend(loc = 'best')

# %%
#poly_regression((reg_df.total_ppg), reg_df.over_under_line, [1,2],15,85, 25, 65,10,150)
log_log_regression(reg_df.total_ppg, reg_df.over_under_line, [1,2,3],3,4.4,3.2,4.2,0,5)
#log_log_regression(reg_df.total_ppg, reg_df.over_under_line, [1,2,3],-15,85,3.2,4.2,15,75)#log-linear reg, change logx to x in function

# %%
def log_regression_evaluation(target, X_list):
    
    split = train_test_split(np.log(X_list+.01), np.log(np.abs(target)+.01))
    ##split = train_test_split(X_list, np.log(np.abs(target)+.01))## log-linear eval
    X_train, X_test, y_train, y_test = split[0], split[1], split[2],split[3]
    X = X_train
    target = y_train
    
    X2 = sm.add_constant(X)

    est = sm.OLS(target, X2)
    est2 = est.fit()
    
    y_predicted = est2.fittedvalues
    y_actual = target
    log_rmse = math.sqrt(mean_squared_log_error(y_actual, y_predicted))
    residuals = y_actual-y_predicted

    #plt.scatter(y_predicted,residuals)
    print(est2.summary())
    sns.distplot(residuals)
    print('Log RMSE=' + str(log_rmse))

# %% [markdown]
# ## all variable over/under log_reg eval

# %%
test_df = reg_df[(reg_df.schedule_week>4)]
test_df[test_df.weather_detail=='DOME']
test_df['dome'] = np.where(test_df['weather_detail']=='DOME', 1, 0)
# Out:
#       schedule_season  schedule_week           team_home  \
# 5431             2002              5     Atlanta Falcons
# 5437             2002              5  Indianapolis Colts
# 5440             2002              5  New Orleans Saints
# 5448             2002              6      Houston Texans
# 5449             2002              6  Indianapolis Colts
# 5450             2002              6   Minnesota Vikings
# 5454             2002              6      St. Louis Rams
# 5460             2002              7     Atlanta Falcons
# 5463             2002              7       Detroit Lions
# 5467             2002              7  New Orleans Saints
# 5471             2002              7      St. Louis Rams
# 5480             2002              8   Minnesota Vikings
# 5482             2002              8  New Orleans Saints
# 5488             2002              9     Atlanta Falcons
# 5492             2002              9       Detroit Lions
# 5493             2002              9      Houston Texans
# 5494             2002              9  Indianapolis Colts
# 5507             2002             10   Minnesota Vikings
# 5515             2002             11     Atlanta Falcons
# 5517             2002             11       Detroit Lions
# 5518             2002             11      Houston Texans
# 5519             2002             11  Indianapolis Colts
# 5522             2002             11   Minnesota Vikings
# 5530             2002             11      St. Louis Rams
# 5537             2002             12      Houston Texans
# 5540             2002             12  New Orleans Saints
# 5548             2002             13       Detroit Lions
# 5553             2002             13  Indianapolis Colts
# 5556             2002             13   Minnesota Vikings
# 5557             2002             13  New Orleans Saints
# ...               ...            ...                 ...
# 9509             2017             10     Atlanta Falcons
# 9513             2017             10       Detroit Lions
# 9514             2017             10  Indianapolis Colts
# 9525             2017             11      Dallas Cowboys
# 9531             2017             11   Minnesota Vikings
# 9532             2017             11  New Orleans Saints
# 9536             2017             12      Dallas Cowboys
# 9537             2017             12       Detroit Lions
# 9539             2017             12   Arizona Cardinals
# 9540             2017             12     Atlanta Falcons
# 9542             2017             12  Indianapolis Colts
# 9552             2017             13      Dallas Cowboys
# 9553             2017             13   Arizona Cardinals
# 9554             2017             13     Atlanta Falcons
# 9562             2017             13  New Orleans Saints
# 9568             2017             14     Atlanta Falcons
# 9569             2017             14   Arizona Cardinals
# 9575             2017             14      Houston Texans
# 9584             2017             15  Indianapolis Colts
# 9585             2017             15       Detroit Lions
# 9591             2017             15   Minnesota Vikings
# 9592             2017             15  New Orleans Saints
# 9602             2017             16   Arizona Cardinals
# 9606             2017             16      Dallas Cowboys
# 9609             2017             16  New Orleans Saints
# 9614             2017             16      Houston Texans
# 9616             2017             17     Atlanta Falcons
# 9619             2017             17       Detroit Lions
# 9620             2017             17  Indianapolis Colts
# 9624             2017             17   Minnesota Vikings
#
#                  team_away team_favorite_id  spread_favorite  over_under_line  \
# 5431  Tampa Bay Buccaneers              ATL             -2.5             38.5
# 5437    Cincinnati Bengals              IND            -13.5             43.0
# 5440   Pittsburgh Steelers               NO             -3.0             43.5
# 5448         Buffalo Bills              BUF             -7.0             44.0
# 5449      Baltimore Ravens              IND             -6.5             42.0
# 5450         Detroit Lions              MIN             -4.5             49.0
# 5454       Oakland Raiders              OAK             -7.0             49.0
# 5460     Carolina Panthers              ATL             -4.0             35.5
# 5463         Chicago Bears              CHI             -3.0             44.5
# 5467   San Francisco 49ers               NO             -1.5             48.5
# 5471      Seattle Seahawks              LAR             -6.5             44.5
# 5480         Chicago Bears              MIN             -2.0             46.0
# 5482       Atlanta Falcons               NO             -3.5             47.0
# 5488      Baltimore Ravens              ATL             -7.0             40.5
# 5492        Dallas Cowboys              DET             -3.0             37.0
# 5493    Cincinnati Bengals              HOU             -2.5             36.5
# 5494      Tennessee Titans              IND             -3.0             47.0
# 5507       New York Giants              NYG             -1.5             45.0
# 5515    New Orleans Saints              ATL             -1.5             51.0
# 5517         New York Jets              NYJ             -3.0             43.0
# 5518  Jacksonville Jaguars              JAX             -6.5             36.5
# 5519        Dallas Cowboys              IND             -6.5             39.5
# 5522     Green Bay Packers               GB             -6.5             50.5
# 5530         Chicago Bears              LAR            -10.5             43.5
# 5537       New York Giants              NYG             -5.5             34.0
# 5540      Cleveland Browns               NO             -5.5             48.5
# 5548  New England Patriots               NE             -6.0             46.0
# 5553        Houston Texans              IND            -11.5             39.5
# 5556       Atlanta Falcons              ATL             -3.5             47.5
# 5557  Tampa Bay Buccaneers               TB             -1.5             40.0
# ...                    ...              ...              ...              ...
# 9509        Dallas Cowboys              ATL             -3.5             49.0
# 9513      Cleveland Browns              DET            -10.5             42.5
# 9514   Pittsburgh Steelers              PIT            -10.5             47.0
# 9525   Philadelphia Eagles              PHI             -6.0             48.0
# 9531      Los Angeles Rams              MIN             -2.5             45.5
# 9532   Washington Redskins               NO             -7.5             52.5
# 9536  Los Angeles Chargers              LAC             -1.0             48.0
# 9537     Minnesota Vikings              MIN             -3.0             44.5
# 9539  Jacksonville Jaguars              JAX             -5.0             38.0
# 9540  Tampa Bay Buccaneers              ATL            -10.0             48.5
# 9542      Tennessee Titans              TEN             -3.5             44.0
# 9552   Washington Redskins              WAS             -2.0             47.0
# 9553      Los Angeles Rams              LAR             -7.0             44.5
# 9554     Minnesota Vikings              ATL             -3.0             47.0
# 9562     Carolina Panthers               NO             -4.5             48.0
# 9568    New Orleans Saints              ATL             -2.5             51.5
# 9569      Tennessee Titans              TEN             -2.5             42.0
# 9575   San Francisco 49ers              HOU             -1.0             45.5
# 9584        Denver Broncos              DEN             -3.0             40.5
# 9585         Chicago Bears              DET             -5.0             43.5
# 9591    Cincinnati Bengals              MIN            -12.5             42.5
# 9592         New York Jets               NO            -16.5             47.0
# 9602       New York Giants              ARI             -3.0             39.0
# 9606      Seattle Seahawks              DAL             -4.5             47.0
# 9609       Atlanta Falcons               NO             -5.5             52.0
# 9614   Pittsburgh Steelers              PIT             -8.0             45.5
# 9616     Carolina Panthers              ATL             -5.0             44.5
# 9619     Green Bay Packers              DET             -7.5             44.5
# 9620        Houston Texans              IND             -5.5             41.5
# 9624         Chicago Bears              MIN            -13.5             38.5
#
#      weather_detail  weather_temperature  weather_wind_mph  \
# 5431           DOME                 72.0               0.0
# 5437           DOME                 72.0               0.0
# 5440           DOME                 72.0               0.0
# 5448           DOME                 72.0               0.0
# 5449           DOME                 72.0               0.0
# 5450           DOME                 72.0               0.0
# 5454           DOME                 72.0               0.0
# 5460           DOME                 72.0               0.0
# 5463           DOME                 72.0               0.0
# 5467           DOME                 72.0               0.0
# 5471           DOME                 72.0               0.0
# 5480           DOME                 72.0               0.0
# 5482           DOME                 72.0               0.0
# 5488           DOME                 72.0               0.0
# 5492           DOME                 72.0               0.0
# 5493           DOME                 72.0               0.0
# 5494           DOME                 72.0               0.0
# 5507           DOME                 72.0               0.0
# 5515           DOME                 72.0               0.0
# 5517           DOME                 72.0               0.0
# 5518           DOME                 72.0               0.0
# 5519           DOME                 72.0               0.0
# 5522           DOME                 72.0               0.0
# 5530           DOME                 72.0               0.0
# 5537           DOME                 72.0               0.0
# 5540           DOME                 72.0               0.0
# 5548           DOME                 72.0               0.0
# 5553           DOME                 72.0               0.0
# 5556           DOME                 72.0               0.0
# 5557           DOME                 72.0               0.0
# ...             ...                  ...               ...
# 9509           DOME                 72.0               0.0
# 9513           DOME                 72.0               0.0
# 9514           DOME                 72.0               0.0
# 9525           DOME                 72.0               0.0
# 9531           DOME                 72.0               0.0
# 9532           DOME                 72.0               0.0
# 9536           DOME                 72.0               0.0
# 9537           DOME                 72.0               0.0
# 9539           DOME                 72.0               0.0
# 9540           DOME                 72.0               0.0
# 9542           DOME                 72.0               0.0
# 9552           DOME                 72.0               0.0
# 9553           DOME                 72.0               0.0
# 9554           DOME                 72.0               0.0
# 9562           DOME                 72.0               0.0
# 9568           DOME                 72.0               0.0
# 9569           DOME                 72.0               0.0
# 9575           DOME                 72.0               0.0
# 9584           DOME                 72.0               0.0
# 9585           DOME                 72.0               0.0
# 9591           DOME                 72.0               0.0
# 9592           DOME                 72.0               0.0
# 9602           DOME                 72.0               0.0
# 9606           DOME                 72.0               0.0
# 9609           DOME                 72.0               0.0
# 9614           DOME                 72.0               0.0
# 9616           DOME                 72.0               0.0
# 9619           DOME                 72.0               0.0
# 9620           DOME                 72.0               0.0
# 9624           DOME                 72.0               0.0
#
#               ...           away_pt_diff_pg  pt_diff_pg  home_exp_win_pct  \
# 5431          ...                    14.750      -7.083          0.881827
# 5437          ...                   -24.000      29.000          0.810542
# 5440          ...                    -8.667      14.167          0.785183
# 5448          ...                    -3.400      -9.100          0.015830
# 5449          ...                    -3.000       8.500          0.820127
# 5450          ...                   -13.250       2.750          0.102316
# 5454          ...                    18.000     -28.200          0.052315
# 5460          ...                     4.500      -1.300          0.719684
# 5463          ...                    -4.000      -8.000          0.066413
# 5467          ...                     6.800       0.033          0.817259
# 5471          ...                    -2.000      -4.000          0.158086
# 5480          ...                    -3.833      -4.167          0.142532
# 5482          ...                     7.667      -0.667          0.819719
# 5488          ...                    -2.857       9.714          0.868274
# 5492          ...                    -4.750      -4.393          0.107656
# 5493          ...                   -19.429       9.143          0.051616
# 5494          ...                    -5.286       5.429          0.509654
# 5507          ...                    -2.375      -3.125          0.221245
# 5515          ...                     6.333       0.042          0.822088
# 5517          ...                    -4.778      -5.000          0.083232
# 5518          ...                     2.889     -15.556          0.023447
# 5519          ...                    -4.444       6.111          0.610114
# 5522          ...                     9.889     -15.556          0.212919
# 5530          ...                    -5.556       5.334          0.485509
# 5537          ...                    -1.000     -10.700          0.032889
# 5540          ...                     1.700       3.300          0.745596
# 5548          ...                     4.000     -13.818          0.078721
# 5553          ...                   -10.455      13.637          0.706962
# 5556          ...                     9.000     -13.364          0.265318
# 5557          ...                    11.000      -7.273          0.693808
# ...           ...                       ...         ...               ...
# 9509          ...                     6.000      -6.250          0.483535
# 9513          ...                   -10.375      12.875          0.644783
# 9514          ...                     4.500     -15.500          0.059276
# 9525          ...                    11.556      -8.445          0.678320
# 9531          ...                    14.889      -9.111          0.823493
# 9532          ...                    -2.778      14.222          0.943648
# 9536          ...                     2.500      -2.500          0.500000
# 9537          ...                     6.900      -3.200          0.703409
# 9539          ...                    10.400     -18.200          0.112083
# 9540          ...                    -2.500       4.600          0.632119
# 9542          ...                    -3.100      -7.100          0.069231
# 9552          ...                    -1.636      -0.364          0.379637
# 9553          ...                    11.182     -18.000          0.144089
# 9554          ...                     6.909      -3.727          0.691855
# 9562          ...                     3.727       5.364          0.898074
# 9568          ...                     9.167      -6.667          0.658110
# 9569          ...                    -1.333      -6.250          0.122018
# 9575          ...                    -8.000       6.917          0.437147
# 9584          ...                    -6.615      -3.539          0.060963
# 9585          ...                    -3.846       4.538          0.539768
# 9591          ...                    -3.462       9.154          0.822485
# 9592          ...                    -3.462      11.693          0.879684
# 9602          ...                    -9.071       2.571          0.146717
# 9606          ...                     2.000      -0.214          0.609347
# 9609          ...                     2.571       5.929          0.886235
# 9614          ...                     4.714      -9.071          0.263783
# 9616          ...                     3.200      -1.467          0.612968
# 9619          ...                    -2.667       3.334          0.539433
# 9620          ...                    -5.933      -4.134          0.060798
# 9624          ...                    -2.867      10.667          0.898731
#
#       away_exp_win_pct home_win_pct_last_4  away_win_pct_last_4  \
# 5431          0.988403                0.25                0.750
# 5437          0.000151                0.50                0.000
# 5440          0.080456                0.75                0.250
# 5448          0.347696                0.00                0.500
# 5449          0.291326                0.50                0.500
# 5450          0.051047                0.00                0.250
# 5454          0.974734                0.00                0.750
# 5460          0.826482                0.50                0.250
# 5463          0.277259                0.25                0.000
# 5467          0.873095                0.75                0.750
# 5471          0.373705                0.25                0.250
# 5480          0.282554                0.25                0.000
# 5482          0.912238                0.75                0.500
# 5488          0.304373                0.75                0.500
# 5492          0.173124                0.25                0.250
# 5493          0.003153                0.25                0.000
# 5494          0.226731                0.50                0.500
# 5507          0.310524                0.50                0.250
# 5515          0.791417                0.75                0.500
# 5517          0.221994                0.50                0.750
# 5518          0.692224                0.25                0.250
# 5519          0.179049                0.25                0.000
# 5522          0.914700                0.25                0.750
# 5530          0.198777                0.75                0.000
# 5537          0.420837                0.25                0.750
# 5540          0.606769                0.25                0.500
# 5548          0.726777                0.25                0.750
# 5553          0.045079                0.75                0.250
# 5556          0.916602                0.25                0.875
# 5557          0.972284                0.25                0.750
# ...                ...                 ...                  ...
# 9509          0.802900                0.25                0.750
# 9513          0.050676                0.25                0.000
# 9514          0.788763                0.25                0.750
# 9525          0.937375                0.75                0.750
# 9531          0.972155                0.75                0.750
# 9532          0.339659                1.00                0.250
# 9536          0.661893                0.50                0.250
# 9537          0.867902                0.75                0.750
# 9539          0.953803                0.25                0.750
# 9540          0.341723                0.75                0.500
# 9542          0.319310                0.25                0.500
# 9552          0.403055                0.25                0.500
# 9553          0.938649                0.50                0.750
# 9554          0.864059                0.75                0.750
# 9562          0.732822                0.75                0.750
# 9568          0.899110                0.75                0.750
# 9569          0.417072                0.25                0.750
# 9575          0.101994                0.25                0.500
# 9584          0.143583                0.00                0.250
# 9585          0.249407                0.50                0.250
# 9591          0.270435                0.75                0.500
# 9592          0.291274                0.50                0.250
# 9602          0.077509                0.50                0.000
# 9606          0.626589                0.75                0.500
# 9609          0.663117                0.50                0.750
# 9614          0.770695                0.00                0.750
# 9616          0.696132                0.50                0.750
# 9619          0.333942                0.50                0.500
# 9620          0.195460                0.00                0.000
# 9624          0.300399                0.75                0.500
#
#      exp_win_difference total_ppg  total_points_against  last_four_difference
# 5431          -0.106576     52.17                 29.75                -0.500
# 5437           0.810391     27.08                 46.08                 0.500
# 5440           0.704727     43.42                 46.58                 0.500
# 5448          -0.331866     43.10                 59.00                -0.500
# 5449           0.528801     39.75                 37.25                 0.000
# 5450           0.051269     46.00                 69.75                -0.250
# 5454          -0.922419     55.30                 47.50                -0.750
# 5460          -0.106798     37.00                 29.30                 0.250
# 5463          -0.210845     44.20                 60.20                 0.250
# 5467          -0.055837     54.00                 40.37                 0.000
# 5471          -0.215619     38.00                 46.00                 0.000
# 5480          -0.140022     44.83                 56.66                 0.250
# 5482          -0.092519     53.24                 38.57                 0.250
# 5488           0.563901     41.29                 37.29                 0.250
# 5492          -0.065468     34.79                 48.68                 0.000
# 5493           0.048463     25.57                 55.28                 0.250
# 5494           0.282923     43.57                 48.71                 0.000
# 5507          -0.089280     37.37                 45.25                 0.250
# 5515           0.030671     59.84                 47.14                 0.250
# 5517          -0.138762     38.33                 52.89                -0.250
# 5518          -0.668777     34.11                 43.89                 0.000
# 5519           0.431064     34.45                 37.22                 0.250
# 5522          -0.701781     52.56                 48.34                -0.500
# 5530           0.286731     41.78                 47.56                 0.750
# 5537          -0.387948     29.70                 42.40                -0.500
# 5540           0.138827     53.90                 47.20                -0.250
# 5548          -0.648056     44.18                 50.00                -0.500
# 5553           0.661883     35.64                 42.90                 0.500
# 5556          -0.651284     49.09                 44.45                -0.625
# 5557          -0.278475     51.72                 37.00                -0.500
# ...                 ...       ...                   ...                   ...
# 9509          -0.319365     49.50                 43.75                -0.500
# 9513           0.594107     40.63                 48.50                 0.250
# 9514          -0.729487     38.77                 45.27                -0.500
# 9525          -0.259055     57.33                 42.67                 0.000
# 9531          -0.148662     57.00                 36.33                 0.000
# 9532           0.603989     52.78                 44.11                 0.750
# 9536          -0.161893     46.30                 43.80                 0.250
# 9537          -0.164493     51.20                 40.60                 0.000
# 9539          -0.841720     42.10                 39.50                -0.500
# 9540           0.290396     43.40                 43.80                 0.250
# 9542          -0.250079     40.00                 53.30                -0.250
# 9552          -0.023418     46.00                 49.64                -0.250
# 9553          -0.794559     48.36                 44.00                -0.250
# 9554          -0.172204     48.73                 38.64                 0.000
# 9562           0.165252     51.82                 39.00                 0.000
# 9568          -0.241000     52.25                 40.58                 0.000
# 9569          -0.295053     40.42                 49.33                -0.500
# 9575           0.335153     41.50                 50.58                -0.250
# 9584          -0.082620     33.85                 50.61                -0.250
# 9585           0.290361     43.23                 46.39                 0.250
# 9591           0.552050     41.15                 38.93                 0.250
# 9592           0.588410     48.92                 44.15                 0.250
# 9602           0.069208     33.86                 49.43                 0.500
# 9606          -0.017242     46.93                 43.14                 0.250
# 9609           0.223117     51.35                 40.28                -0.250
# 9614          -0.506911     47.36                 47.00                -0.750
# 9616          -0.083164     45.60                 40.66                -0.250
# 9619           0.205491     45.60                 47.60                 0.000
# 9620          -0.134662     37.67                 53.67                 0.000
# 9624           0.598332     40.86                 35.93                 0.250
#
# [725 rows x 52 columns]

# %%
log_regression_evaluation(test_df.over_under_line, test_df[['dome','weather_wind_mph', 'weather_humidity', 'total_points_against', 'total_ppg','weather_temperature']].values)
regression_evaluation(test_df.over_under_line, test_df[['dome','weather_wind_mph', 'weather_humidity', 'total_points_against', 'total_ppg','weather_temperature']].values)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.683
# Method:                 Least Squares   F-statistic:                     839.6
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        19:57:29   Log-Likelihood:                 3162.7
# No. Observations:                2332   AIC:                            -6311.
# Df Residuals:                    2325   BIC:                            -6271.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7245      0.057     12.804      0.000       0.614       0.835
# x1             0.0008      0.002      0.445      0.656      -0.003       0.004
# x2            -0.0046      0.001     -3.868      0.000      -0.007      -0.002
# x3            -0.0157      0.006     -2.731      0.006      -0.027      -0.004
# x4             0.3355      0.009     38.638      0.000       0.318       0.352
# x5             0.4567      0.008     57.923      0.000       0.441       0.472
# x6             0.0298      0.004      8.105      0.000       0.023       0.037
# ==============================================================================
# Omnibus:                       26.757   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.225
# Skew:                          -0.155   Prob(JB):                     2.24e-08
# Kurtosis:                       3.516   Cond. No.                         386.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Log RMSE=0.013141375855090091
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     1162.
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        19:57:29   Log-Likelihood:                -7436.9
# No. Observations:                3110   AIC:                         1.489e+04
# Df Residuals:                    3103   BIC:                         1.493e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.0138      0.587     15.360      0.000       7.863      10.164
# x1             0.7825      0.154      5.088      0.000       0.481       1.084
# x2            -0.0898      0.011     -8.173      0.000      -0.111      -0.068
# x3            -0.0140      0.004     -3.670      0.000      -0.022      -0.007
# x4             0.3244      0.007     43.656      0.000       0.310       0.339
# x5             0.4558      0.007     68.178      0.000       0.443       0.469
# x6             0.0224      0.004      6.280      0.000       0.015       0.029
# ==============================================================================
# Omnibus:                       14.569   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.729
# Skew:                           0.004   Prob(JB):                     5.20e-05
# Kurtosis:                       3.390   Cond. No.                     1.33e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# RMSE=2.6441046366000514, check =-0.0
# /Users/SamLiebman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
regression_evaluation(reg_df.over_under_line, reg_df.total_ppg)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     2218.
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        19:57:30   Log-Likelihood:                -10529.
# No. Observations:                3841   AIC:                         2.106e+04
# Df Residuals:                    3839   BIC:                         2.107e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.1329      0.326     86.404      0.000      27.495      28.771
# total_ppg      0.3450      0.007     47.097      0.000       0.331       0.359
# ==============================================================================
# Omnibus:                        5.897   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                5.885
# Skew:                          -0.096   Prob(JB):                       0.0527
# Kurtosis:                       3.008   Cond. No.                         239.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=3.7517656568252153, check =0.0

# %%
log_regression_evaluation(reg_df.over_under_line, reg_df.total_ppg)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        over_under_line   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     1575.
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):          4.17e-275
# Time:                        19:23:01   Log-Likelihood:                 2900.8
# No. Observations:                2880   AIC:                            -5798.
# Df Residuals:                    2878   BIC:                            -5786.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4158      0.009    385.999      0.000       3.398       3.433
# total_ppg      0.0079      0.000     39.686      0.000       0.008       0.008
# ==============================================================================
# Omnibus:                       69.288   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.739
# Skew:                          -0.387   Prob(JB):                     9.72e-17
# Kurtosis:                       3.128   Cond. No.                         238.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RMSE=0.01865664255879451
# /Users/SamLiebman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
log_log_regression(reg_df.total_ppg,reg_df.over_under_line,[1,2],3,4.25,3.2,4.2,0,5)
