# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('spreadspoke_scores.csv')
df.dtypes
# Out:
# schedule_date          datetime64[ns]
# schedule_season                 int64
# schedule_week                  object
# team_home                      object
# team_away                      object
# stadium                        object
# team_favorite_id               object
# spread_favorite               float64
# over_under_line               float64
# weather_detail                 object
# weather_temperature           float64
# weather_wind_mph              float64
# weather_humidity              float64
# score_home                      int64
# score_away                      int64
# stadium_neutral                  bool
# schedule_playoff                 bool
# game_id                        object
# favorite_covered                int64
# over_under_result              object
# point_total                     int64
# score_difference                int64
# dtype: object

# %%
df = df.dropna(subset=['team_favorite_id', 'spread_favorite', 'over_under_line'])

# %%
df = df.apply(pd.to_numeric, errors='ignore')
df['over_under_line']=df['over_under_line'].apply(pd.to_numeric, errors='coerce')
df['schedule_date']=df['schedule_date'].apply(pd.to_datetime)
df.loc[df.team_favorite_id =='SD','team_favorite_id'] = 'LAC'

# %%
special_weather_df = df[(df.weather_detail.isna() == False) & (df.weather_detail != 'DOME')]

# %%
df.dtypes
# Out:
# schedule_date          datetime64[ns]
# schedule_season                 int64
# schedule_week                  object
# team_home                      object
# team_away                      object
# stadium                        object
# team_favorite_id               object
# spread_favorite               float64
# over_under_line               float64
# weather_detail                 object
# weather_temperature           float64
# weather_wind_mph              float64
# weather_humidity              float64
# score_home                      int64
# score_away                      int64
# stadium_neutral                  bool
# schedule_playoff                 bool
# game_id                        object
# dtype: object

# %%
df.tail(20)
# Out:
#       schedule_date  schedule_season schedule_week             team_home  \
# 12124    2017-12-31             2017            17        Miami Dolphins
# 12125    2017-12-31             2017            17     Minnesota Vikings
# 12126    2017-12-31             2017            17  New England Patriots
# 12127    2017-12-31             2017            17       New York Giants
# 12128    2017-12-31             2017            17   Philadelphia Eagles
# 12129    2017-12-31             2017            17   Pittsburgh Steelers
# 12130    2017-12-31             2017            17      Seattle Seahawks
# 12131    2017-12-31             2017            17  Tampa Bay Buccaneers
# 12132    2017-12-31             2017            17      Tennessee Titans
# 12133    2018-01-06             2017      Wildcard    Kansas City Chiefs
# 12134    2018-01-06             2017      Wildcard      Los Angeles Rams
# 12135    2018-01-07             2017      Wildcard  Jacksonville Jaguars
# ...

# %%
#different game type masks
playoff_mask = df['schedule_playoff']==True
playoffs = df[playoff_mask]
reg_seas_mask = df['schedule_playoff']==False
reg_season = df[reg_seas_mask]
sb_mask = df['schedule_week']=='Superbowl'
sb = df[sb_mask]

# %%
# spread_ou = df.as_matrix(columns=['spread_favorite','over_under_line'])
# x = -spread_ou[:,0]
# y= spread_ou[:,1]

# fig = plt.figure(figsize=(10,5))
# plt.scatter(x,y)
# plt.xlabel('Betting Line (favorite favored by x points)')
# plt.ylabel('Over/Under');

# sb_ou_temp = sb.as_matrix(columns = ['over_under_line','weather_temperature'])
# sb_x = sb_ou_temp[:,0]
# sb_y = sb_ou_temp[:,1]

# ax_sb = sns.regplot(sb_x,sb_y)
# ax_sb.set(xlabel='over under',ylabel='temp (f)');

# %%
df.head()
# Out:
#      schedule_date  schedule_season schedule_week           team_home  \
# 350     1968-01-14             1967     Superbowl   Green Bay Packers
# 538     1969-01-12             1968     Superbowl     Baltimore Colts
# 727     1970-01-11             1969     Superbowl  Kansas City Chiefs
# 916     1971-01-17             1970     Superbowl     Baltimore Colts
# 1105    1972-01-16             1971     Superbowl      Dallas Cowboys
#
#               team_away         stadium team_favorite_id  spread_favorite  \
# 350     Oakland Raiders     Orange Bowl               GB            -13.5
# 538       New York Jets     Orange Bowl              BAL            -18.0
# 727   Minnesota Vikings  Tulane Stadium              MIN            -12.0
# 916      Dallas Cowboys     Orange Bowl              BAL             -2.5
# 1105     Miami Dolphins  Tulane Stadium              DAL             -6.0
#
#       over_under_line                                     weather_detail  \
# ...

# %%
df['point_total'] = df['score_home'] + df['score_away']

# %%
df['over_under_result'] = np.where(df['point_total']>df['over_under_line'], 'over', 'under')
df['over_under_result'] = np.where(df['point_total']==df['over_under_line'], 'push', df['over_under_result'])

# %%
df['score_difference'] = df['score_home'] - df['score_away']

# %%
team_ids=[]
for game_id in game_ids:
    if game_id == 0:
        team_ids.append(game_id)
    else:
        team_ids.append(game_id[8:])

# %%
fav_ids = df.team_favorite_id
fav_ids = list(set(fav_ids))
fav_ids
# Out:
# ['MIN',
#  'CHI',
#  'LAR',
#  'LAC',
#  'JAX',
#  'HOU',
#  'PHI',
#  'IND',
#  'DEN',
#  'WAS',
#  'NE',
#  'ATL',
#  'TEN',
#  'NYG',
#  'NYJ',
#  'CIN',
#  'CLE',
#  'ARI',
#  'DAL',
#  'SF',
#  'CAR',
#  'KC',
#  'GB',
#  'TB',
#  'NO',
#  'BUF',
#  'SEA',
#  'PIT',
#  'PICK',
#  'DET',
#  'MIA',
#  'OAK',
#  'BAL']

# %%
team_ids
# Out:
# ['OAKGB',
#  'NYJIND',
#  'MINKC',
#  'DALIND',
#  'MIADAL',
#  'WASMIA',
#  'MINMIA',
#  'PITMIN',
#  'PITDAL',
#  'OAKMIN',
#  'DENDAL',
#  'PITDAL',
#  'DETTB',
#  'MIABUF',
#  'GBCHI',
#  'CINDEN',
#  'INDKC',
#  'OAKLAR',
#  'SFMIN',
#  'ATLNO',
#  'CLENYJ',
#  'NYGPHI',
#  'LACSEA',
#  'DALARI',
#  'TENWAS',
#  'PITNE',
#  'LARDEN',
#  'TBIND',
#  'CINBUF',
#  'MINCHI',
#  'WASDET',
#  'NOGB',
#  'CLEKC',
#  'SEAMIA',
#  'NYJNE',
#  'ARINYG',
#  'TENPIT',
#  'OAKLAC',
#  'DALSF',
#  'ATLPHI',
#  'DENATL',
#  'NECIN',
#  'INDCLE',
#  'CHIDAL',
#  'TBGB',
#  'KCTEN',
#  'SFLAR',
#  'MIAMIN',
#  'PHINO',
#  'DETNYJ',
#  'BUFLAC',
#  'OAKSEA',
#  'PITARI',
#  'NYGWAS',
#  'NYJBUF',
#  'TENCIN',
#  'SEADEN',
#  'ATLDET',
#  'OAKKC',
#  'CHIMIA',
#  'GBMIN',
#  'LACNE',
#  'PHINYG',
#  'INDPIT',
#  'NOSF',
#  'WASARI',
#  'LARTB',
#  'DALCLE',
#  'WASATL',
#  'BUFIND',
#  'TBCHI',
#  'CINDAL',
#  'MINDET',
#  'CLETEN',
#  'ARILAR',
#  'NYGNO',
#  'MIANYJ',
#  'DENOAK',
#  'PITPHI',
# ...

# %%
team_id_tuples = []
for team_id in team_ids:
    if(len(str(team_id)) ==6):
        team_id_tuples.append((team_id[3:], team_id[:3]))
    else:
        if str(team_id)[:3] in fav_ids:
            team_id_tuples.append((team_id[3:],team_id[:3]))
        else:
            team_id_tuples.append((str(team_id)[2:],str(team_id)[:2]))

# %%
team_ids_array = np.array(team_id_tuples)
team_ids_array
# Out:
# array([['GB', 'OAK'],
#        ['IND', 'NYJ'],
#        ['KC', 'MIN'],
#        ...,
#        ['', '0'],
#        ['', '0'],
#        ['', '0']], dtype='<U3')

# %%
df['home_id'] = team_ids_array[:,0]
df['away_id'] = team_ids_array[:,1]
df['home_favorite'] = np.where(df['team_favorite_id']==df['home_id'],1,0)

# %%
df.head()
# Out:
#      schedule_date  schedule_season schedule_week           team_home  \
# 350     1968-01-14             1967     Superbowl   Green Bay Packers
# 538     1969-01-12             1968     Superbowl     Baltimore Colts
# 727     1970-01-11             1969     Superbowl  Kansas City Chiefs
# 916     1971-01-17             1970     Superbowl     Baltimore Colts
# 1105    1972-01-16             1971     Superbowl      Dallas Cowboys
#
#               team_away         stadium team_favorite_id  spread_favorite  \
# 350     Oakland Raiders     Orange Bowl               GB            -13.5
# 538       New York Jets     Orange Bowl              BAL            -18.0
# 727   Minnesota Vikings  Tulane Stadium              MIN            -12.0
# 916      Dallas Cowboys     Orange Bowl              BAL             -2.5
# 1105     Miami Dolphins  Tulane Stadium              DAL             -6.0
#
#       over_under_line                                     weather_detail  \
# ...

# %%
#determine whether favorite covered the spread, or push if even
#need to fix error where home_id != favorite (ex: baltimore colts id is IND bc they moved)
df['favorite_covered'] = np.where((df.home_favorite==1) & (np.abs(df.score_difference) > np.abs(df.spread_favorite)),1,0)
df['favorite_covered'] = np.where((df.home_favorite==0) & (np.abs(df.score_difference) < np.abs(df.spread_favorite)),1,df.home_favorite)
df['favorite_covered'] = np.where((np.abs(df.score_difference) == np.abs(df.spread_favorite)),'push',df.home_favorite)
